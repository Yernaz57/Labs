# %% [markdown]
# <a href="https://colab.research.google.com/github/Yernaz57/Labs/blob/master/IRIS_seaborn_yernaz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)

iris = sns.load_dataset("iris")

plots1 = sns.pairplot(iris)

print(plots1)
# there is plots sns pairplot with iris

# %%
# there is plots sns pairplot with iris, hue

plots2 = sns.pairplot(iris, hue="species");
print(plots2)

# %%
# there is plots sns pairplot with iris, hue, markers

plots_3 = sns.pairplot(iris, hue="species", markers=["o", "s", "D"]);
print(plots_3)

# %%
# there is plot with subset variables

plot_subset_var = sns.pairplot(iris, vars=["sepal_width", "sepal_length"]);
print(plot_subset_var)

# %%
# there is showing plot with density estimate

plot_with_density_estimate = sns.pairplot(iris, diag_kind="kde"); 
print(plot_with_density_estimate)

# %%
plot_with_reg = sns.pairplot(iris, kind="reg");
print(plot_with_reg)
